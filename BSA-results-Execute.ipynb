# %%
from  BSA_results_script import runAnalysisOld
from  BSA_results_script import runAnalysis
from  BSA_results_script import plotResults

# %%
from  BSA_results_script import help

# %%
help()
# Out:
# class encoder :
#     The encoder/decoder class is the base class for all encoder/decoder pairs.
#     Subclasses encode different types of encoding.
#     EncoderLearner is a factory class for fitting encoders to data
#
# 	encoder.compress :
#         given a raw sequence and a model, return a compressed representation.
#
# 	encoder.recon :
#         Recreate the original DataFrame or Series, possibly with errors.
#
# 	encoder.get_size :
#         Get size of compressed representation
#
# 	encoder.compute_error :
#         Compute mean sq error for compressed representation
#
# class piecewise_constant :
#     Represent the signal using a sequence of piecewise constant functions
#
# 	piecewise_constant.fit :
#         fit uses dynamic programming to find the best piecewise constant solution
#
# 	piecewise_constant.compress :
#         compress the data
#
# 	piecewise_constant.recon :
#         reconstruct compressed representation
#
# class piecewise_linear :
#     Represent the signal using a sequence of piecewise linear functions
#
# 	piecewise_linear.fit :
#         fit uses dynamic programming to find the best piecewise linear solution
#
# 	piecewise_linear.compress :
#         compress the piecewise linear data
#
# 	piecewise_linear.recon :
#         reconstruct the compressed piecewise linear data
#
# runAnalysisOld :
#     run old analysis on room, template, start and end time, method and tolerance
#
# loadf :
#     load data with room, template, start and end time
#
# dataPlot :
#     data plot for the arguement with lower and upper time boundary
#
# model :
#     use the model based on the method and tolerance
#
# runAnalysis :
#       run analysis based on the template on the data with start and end time
#
# getTime :
#     get the timeseries from the data
#
# plotResults :
#       plot templates on the compression analysis
#
# loadTags :
#     load tags.json

# %%
[dfs,plotTemplates]=runAnalysis(table='rm4226',stTime='2013-12-01',enTime='2013-12-07',templateCount=1)
print len(dfs)
print plotTemplates
plotResults(dfs,plotTemplates)
# Out:
# select * from rm4226 where template='Zone Temperature' and timeseries between '2013-12-01' and '2013-12-07'
# Std dev is  3.3478567606
# range= 15.18
# BSA_results_script.py:235: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   S[np.isnan(S)]=0
# HI
# type is  <class 'pandas.core.series.Series'>
# size= 37 HI
# error= 0.0307097821904 error/_std= 0.00917296777803
# [{'value': 71.450000000000003, 'time': 3920}, {'value': 74.5, 'time': 3825}, {'value': 75.519999999999996, 'time': 3729}, {'value': 69.959999999999994, 'time': 3633}, {'value': 68.480000000000004, 'time': 3537}, {'value': 69.980000000000004, 'time': 3153}, {'value': 70.480000000000004, 'time': 3057}, {'value': 71.510000000000005, 'time': 2961}, {'value': 72.019999999999996, 'time': 2865}, {'value': 71.510000000000005, 'time': 2769}, {'value': 70.510000000000005, 'time': 2577}, {'value': 70.510000000000005, 'time': 2481}, {'value': 71.019999999999996, 'time': 2385}, {'value': 71.519999999999996, 'time': 2289}, {'value': 72.530000000000001, 'time': 2097}, {'value': 73.030000000000001, 'time': 2001}, {'value': 76.030000000000001, 'time': 1905}, {'value': 73.519999999999996, 'time': 1809}, {'value': 73.0, 'time': 1713}, {'value': 71.980000000000004, 'time': 1617}, {'value': 72.489999999999995, 'time': 1521}, {'value': 72.989999999999995, 'time': 1425}, {'value': 74.0, 'time': 1329}, {'value': 75.030000000000001, 'time': 1233}, {'value': 77.040000000000006, 'time': 1138}, {'value': 79.549999999999997, 'time': 1042}, {'value': 82.590000000000003, 'time': 946}, {'value': 83.090000000000003, 'time': 852}, {'value': 75.469999999999999, 'time': 761}, {'value': 71.420000000000002, 'time': 665}, {'value': 70.909999999999997, 'time': 569}, {'value': 70.909999999999997, 'time': 473}, {'value': 71.920000000000002, 'time': 377}, {'value': 72.420000000000002, 'time': 281}, {'value': 73.430000000000007, 'time': 185}, {'value': 74.930000000000007, 'time': 92}, {'value': 77.450000000000003, 'time': 0}]
# 2
# ['Zone Temperature']
# 0
# BSA_results_script.py:431: FutureWarning: sort(columns=....) is deprecated, use sort_values(by=.....)
#   ReconDF=ReconDF.sort(['time'], ascending=[1])
# axes1Count 0
# 4017

# %%
dfs=runAnalysisOld('Rm-2219','Zone Temperature','2014-10-10T23:01:45+00:00','2014-10-24T23:59:18+00:00','piecewise_constant',tolerance=96)
# Out:
# 109
# Std dev is  1.91775064281
# range= 5.72
# BSA_results_script.py:146: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   S[np.isnan(S)]=0
# type is  <class 'pandas.core.series.Series'>
# size= 2 error= 0.177448401792 error/_std= 0.0925294445643
# [{'value': 76.4252, 'time': 83}, {'value': 75.29542168674695, 'time': 0}]

# %%
[dfs,plotTemplates]=runAnalysis(table='rm2138',stTime='2013-12-01',enTime='2013-12-07', templateCount=5)
print len(dfs)
print plotTemplates
plotResults(dfs,plotTemplates)
# Out:
# select * from rm2138 where template='Zone Temperature' and timeseries between '2013-12-01' and '2013-12-07'
# Std dev is  nan
# rajeshb Zone Temperature
# select * from rm2138 where template='Actual Supply Flow' and timeseries between '2013-12-01' and '2013-12-07'
# Std dev is  116.768195462
# range= 560.39
# type is  <class 'pandas.core.series.Series'>
# size= 71 error= 0.129878071229 error/_std= 0.00111227265879
# [{'value': 168.33117647058825, 'time': 4863}, {'value': 270.64, 'time': 4860}, {'value': 415.5800000000002, 'time': 4839}, {'value': 528.6576470588235, 'time': 4788}, {'value': 279.29, 'time': 4785}, {'value': 172.79031250000003, 'time': 4689}, {'value': 170.31843749999982, 'time': 4593}, {'value': 171.26843749999992, 'time': 4497}, {'value': 168.59916666666672, 'time': 4425}, {'value': 22.6115, 'time': 4365}, {'value': 18.18374999999999, 'time': 4293}, {'value': 19.397499999999994, 'time': 4197}, {'value': 18.864666666666665, 'time': 4107}, {'value': 27.547826086956533, 'time': 4038}, {'value': 158.68363636363637, 'time': 4005}, {'value': 168.05593750000003, 'time': 3909}, {'value': 265.3344444444445, 'time': 3882}, {'value': 349.25869565217386, 'time': 3813}, {'value': 277.25, 'time': 3801}, {'value': 173.31124999999986, 'time': 3729}, {'value': 163.83653846153854, 'time': 3651}, {'value': 167.38055555555553, 'time': 3597}, {'value': 23.268750000000015, 'time': 3501}, {'value': 26.849687500000016, 'time': 3405}, {'value': 27.39562500000001, 'time': 3309}, {'value': 28.621250000000007, 'time': 3213}, {'value': 31.546129032258072, 'time': 3120}, {'value': 163.1862962962963, 'time': 3039}, {'value': 165.0534375, 'time': 2943}, {'value': 164.10000000000002, 'time': 2847}, {'value': 164.89843750000003, 'time': 2751}, {'value': 167.8254838709677, 'time': 2658}, {'value': 17.848695652173898, 'time': 2589}, {'value': 21.466799999999992, 'time': 2514}, {'value': 23.4590625, 'time': 2418}, {'value': 21.28406249999999, 'time': 2322}, {'value': 22.650937499999994, 'time': 2226}, {'value': 28.155909090909113, 'time': 2160}, {'value': 158.5957142857143, 'time': 2139}, {'value': 168.75999999999996, 'time': 2043}, {'value': 208.65285714285716, 'time': 2022}, {'value': 396.9992307692307, 'time': 1983}, {'value': 535.7308333333333, 'time': 1947}, {'value': 370.48999999999995, 'time': 1941}, {'value': 217.33999999999995, 'time': 1929}, {'value': 166.61781249999996, 'time': 1833}, {'value': 167.52374999999992, 'time': 1737}, {'value': 168.73400000000007, 'time': 1692}, {'value': 3.8403846153846155, 'time': 1614}, {'value': 9.610344827586205, 'time': 1527}, {'value': 8.197199999999997, 'time': 1452}, {'value': 4.5290624999999975, 'time': 1356}, {'value': 3.5678124999999987, 'time': 1260}, {'value': 4.357999999999999, 'time': 1170}, {'value': 17.572333333333336, 'time': 1080}, {'value': 47.89714285714287, 'time': 1059}, {'value': 161.278, 'time': 1044}, {'value': 298.23499999999996, 'time': 1008}, {'value': 386.69461538461564, 'time': 930}, {'value': 522.5439999999999, 'time': 915}, {'value': 95.25, 'time': 912}, {'value': 18.167096774193542, 'time': 819}, {'value': 14.275666666666666, 'time': 729}, {'value': 10.732068965517238, 'time': 642}, {'value': 7.579374999999999, 'time': 546}, {'value': 10.821874999999997, 'time': 450}, {'value': 10.268064516129023, 'time': 357}, {'value': 7.610344827586202, 'time': 270}, {'value': 5.733103448275858, 'time': 183}, {'value': 7.884666666666662, 'time': 93}, {'value': 15.072258064516133, 'time': 0}]
# select * from rm2138 where template='Occupied Clg Min' and timeseries between '2013-12-01' and '2013-12-07'
# Std dev is  nan
# rajeshb Occupied Clg Min
# select * from rm2138 where template='Occupied Htg Flow' and timeseries between '2013-12-01' and '2013-12-07'
# Std dev is  nan
# rajeshb Occupied Htg Flow
# select * from rm2138 where template='Common Setpoint' and timeseries between '2013-12-01' and '2013-12-07'
# Std dev is  nan
# rajeshb Common Setpoint
# 2
# ['Actual Supply Flow']
# 0
# axes0Count 0

# %%
[dfs,plotTemplates]=runAnalysis(table='rm2138',stTime='2014-04-07',enTime='2014-04-14',templateCount=17)
print len(dfs)
print plotTemplates
plotResults(dfs,plotTemplates)
# Out:
# select * from rm2138 where template='Zone Temperature' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Zone Temperature
# select * from rm2138 where template='Actual Supply Flow' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  132.36795097
# range= 551.24
# type is  <class 'pandas.core.series.Series'>
# size= 109 error= 0.119529838875 error/_std= 0.000903011929998
# [{'value': 100.85170731707315, 'time': 6804}, {'value': 375.3066666666666, 'time': 6795}, {'value': 6.540454545454543, 'time': 6729}, {'value': 0.5170967741935484, 'time': 6636}, {'value': 1.6240624999999997, 'time': 6540}, {'value': 0.794375, 'time': 6444}, {'value': 0.586875, 'time': 6348}, {'value': 0.8603125, 'time': 6252}, {'value': 0.2934375, 'time': 6156}, {'value': 1.0015625, 'time': 6060}, {'value': 0.7084375, 'time': 5964}, {'value': 4.083749999999999, 'time': 5892}, {'value': 84.45, 'time': 5877}, {'value': 182.30799999999996, 'time': 5862}, {'value': 363.295, 'time': 5856}, {'value': 73.9, 'time': 5853}, {'value': 5.815312499999998, 'time': 5757}, {'value': 5.9921874999999964, 'time': 5661}, {'value': 6.302499999999998, 'time': 5565}, {'value': 5.045937499999998, 'time': 5469}, {'value': 7.284999999999997, 'time': 5373}, {'value': 4.937812499999997, 'time': 5277}, {'value': 5.958124999999998, 'time': 5181}, {'value': 15.376562500000007, 'time': 5085}, {'value': 167.96217391304359, 'time': 5016}, {'value': 229.83999999999995, 'time': 5007}, {'value': 368.378, 'time': 4992}, {'value': 512.8566666666666, 'time': 4983}, {'value': 412.85800000000006, 'time': 4968}, {'value': 493.54799999999994, 'time': 4953}, {'value': 300.46600000000007, 'time': 4938}, {'value': 546.3533333333334, 'time': 4929}, {'value': 400.07, 'time': 4917}, {'value': 286.60200000000003, 'time': 4902}, {'value': 157.60999999999999, 'time': 4812}, {'value': 159.49500000000015, 'time': 4716}, {'value': 159.1349999999999, 'time': 4620}, {'value': 4.209354838709676, 'time': 4527}, {'value': 8.640937499999996, 'time': 4431}, {'value': 6.211249999999996, 'time': 4335}, {'value': 5.218437499999997, 'time': 4239}, {'value': 12.990312500000003, 'time': 4143}, {'value': 166.24166666666662, 'time': 4071}, {'value': 257.392, 'time': 4041}, {'value': 163.1215625, 'time': 3945}, {'value': 158.00906249999997, 'time': 3849}, {'value': 165.22080000000008, 'time': 3774}, {'value': 171.1081250000002, 'time': 3678}, {'value': 0.22896551724137928, 'time': 3591}, {'value': 2.5748387096774183, 'time': 3498}, {'value': 0.7084375, 'time': 3402}, {'value': 0.8544827586206897, 'time': 3315}, {'value': 3.630344827586206, 'time': 3228}, {'value': 15.297692307692301, 'time': 3189}, {'value': 166.58055555555566, 'time': 3135}, {'value': 449.80499999999984, 'time': 3117}, {'value': 242.94999999999996, 'time': 3108}, {'value': 489.9766666666667, 'time': 3099}, {'value': 323.56999999999994, 'time': 3081}, {'value': 216.38000000000002, 'time': 3075}, {'value': 313.88999999999993, 'time': 3069}, {'value': 414.1866666666666, 'time': 3042}, {'value': 236.33599999999996, 'time': 3027}, {'value': 460.95, 'time': 3024}, {'value': 318.56, 'time': 3018}, {'value': 187.20999999999995, 'time': 3006}, {'value': 411.31, 'time': 3000}, {'value': 272.92777777777786, 'time': 2973}, {'value': 160.5511538461539, 'time': 2895}, {'value': 159.6784375, 'time': 2799}, {'value': 170.3818749999999, 'time': 2703}, {'value': 0.0, 'time': 2610}, {'value': 0.8092857142857144, 'time': 2526}, {'value': 0.5009375, 'time': 2430}, {'value': 0.0, 'time': 2334}, {'value': 0.566875, 'time': 2238}, {'value': 13.500555555555547, 'time': 2184}, {'value': 183.1763157894738, 'time': 2127}, {'value': 367.9066666666665, 'time': 2109}, {'value': 276.88, 'time': 2094}, {'value': 541.4984615384614, 'time': 2055}, {'value': 402.0527272727271, 'time': 2022}, {'value': 535.787, 'time': 1992}, {'value': 372.42, 'time': 1989}, {'value': 282.6358333333332, 'time': 1953}, {'value': 160.24781250000004, 'time': 1857}, {'value': 160.01124999999985, 'time': 1761}, {'value': 171.08600000000004, 'time': 1671}, {'value': 0.0, 'time': 1215}, {'value': 13.146249999999993, 'time': 1143}, {'value': 162.05999999999997, 'time': 1119}, {'value': 337.88000000000005, 'time': 1110}, {'value': 463.8000000000001, 'time': 1095}, {'value': 248.5, 'time': 1089}, {'value': 528.6777419354835, 'time': 996}, {'value': 332.35800000000006, 'time': 981}, {'value' ...
# select * from rm2138 where template='Occupied Clg Min' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Occupied Clg Min
# select * from rm2138 where template='Occupied Htg Flow' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Occupied Htg Flow
# select * from rm2138 where template='Common Setpoint' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Common Setpoint
# select * from rm2138 where template='Actual Heating Setpoint' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Actual Heating Setpoint
# select * from rm2138 where template='Supply Vel Press' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Supply Vel Press
# select * from rm2138 where template='Zone Temperature Error' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Zone Temperature Error
# select * from rm2138 where template='Damper Position' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Damper Position
# select * from rm2138 where template='Warm Cool Adjust' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Warm Cool Adjust
# select * from rm2138 where template='Cooling Command' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Cooling Command
# select * from rm2138 where template='HVAC Zone Power' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb HVAC Zone Power
# select * from rm2138 where template='Damper Command' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Damper Command
# select * from rm2138 where template='Cooling Max Flow' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Cooling Max Flow
# select * from rm2138 where template='Occupied Htg Flow' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Occupied Htg Flow
# select * from rm2138 where template='Actual Cooling Setpoint' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Actual Cooling Setpoint
# select * from rm2138 where template='Reheat Valve Command Error' and timeseries between '2014-04-07' and '2014-04-14'
# Std dev is  nan
# rajeshb Reheat Valve Command Error
# 2
# ['Actual Supply Flow']
# 0
# axes0Count 0
